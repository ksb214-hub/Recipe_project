# %%
import pandas as pd
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if "nutrition" in file:
            print(os.path.join(root, file))
# Out:
# ./nutrition_db.json

# %%
nutrition = pd.read_json("./nutrition_db.json")
nutrition.head(5)
# Out:
#               불고기감 소고기  돼지고기 목살     삼겹살    닭가슴살      새우     오징어     고등어  \
# name          불고기감 소고기  돼지고기 목살     삼겹살    닭가슴살      새우     오징어     고등어
# serving_size     100 g    100 g   100 g   100 g   100 g   100 g   100 g
# kcal               162      264     331     109     106     105     190
# carbs            4.92g     0.6g   0.59g      0g   0.91g   3.53g   0.35g
# protein         16.13g    17.1g  17.24g  22.98g  20.31g  17.86g  17.59g
#
#                   양파     당근     대파  ...        스리라차   머스타드     발사믹 드레싱  \
# name              양파     당근     대파  ...        스리라차   머스타드     발사믹 드레싱
# serving_size   100 g  100 g  100 g  ...  1티스푼 (5 g)  100 g  1회  (30 g)
# kcal              42     41     34  ...           5    285          70
# carbs         10.11g  9.58g   6.5g  ...          1g    27g          6g
# protein        0.92g  0.93g   1.9g  ...          0g     1g          0g
#
#                   라면  데리야끼 소스           칼국수     곤약          두유     프로틴 파우더  \
# name              라면  데리야끼 소스           칼국수     곤약          두유     프로틴 파우더
# serving_size    1 봉지  1 테이블스푼  1 인분 (350 g)  100 g  1회 (190 g)  1스푼 (33 g)
# kcal             385       15           420      7          95         130
# carbs         55.68g    2.87g        71.74g   3.1g          4g          3g
# protein         7.9g    1.07g        16.04g  0.07g          9g         25g
#
#                  수박
# name             수박
# serving_size  100 g
# kcal             30
# carbs         7.55g
# protein       0.61g
#
# [5 rows x 133 columns]
