# %% [markdown]
# # 추천 시스템 개발

# %%
# !pip install scikit-surprise
# 현재의 NumPy를 삭제하고 호환되는 버전으로 재설치합니다.
# !pip install "numpy<2"
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.4
#     Uninstalling numpy-2.4.4:
#       Successfully uninstalled numpy-2.4.4
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 라이브러리
# | 라이브러리 | 역할 | 상세 설명 |
# |---------|-----|---------|
# | pandas | 데이터 핸들링 | CSV, Excel 등 다양한 포맷의 데이터를 불러와 정제, 결측치 처리, 통계 분석을 수행하는 데이터 분석의 필수 도구 |
# | surprise | 추천 알고리즘 | **'개인 맞춤형 레시피 추천 엔진'**을 구현할 때 사용하는 라이브러리 |

# %% [markdown]
# ## 순서도 (Recommendation Flow)
#
# ```mermaid
# flowchart TD
#
# A[DataFrame 데이터 불러오기] --> B[사용자-레시피 데이터 전처리]
#
# B --> C[사용자-아이템 행렬 생성]
#
# C --> D[SVD 행렬 분해 수행]
#
# D --> E[잠재 요인 벡터 생성]
#
# E --> F[사용자 선호도 예측]
#
# F --> G[추천 점수 계산]
#
# G --> H[상위 레시피 추천 반환]
# ```

# %% [markdown]
# ## SVD란?

# %% [markdown]
# ![SVD시각화](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Singular_value_decomposition_visualisation.svg/500px-Singular_value_decomposition_visualisation.svg.png)
#
# 실수나 복소수로 이루어진 체 K의 원소로 구성되는 m × n 행렬 M에 대해, M은 다음과 같은 세 행렬의 곱으로 분해할 수 있다.

# %% [markdown]
# ![SVD 행렬 이미지](https://wikimedia.org/api/rest_v1/media/math/render/svg/0f328557983590429edd6634c99733403bc09c7d)
#
# ![U](https://wikimedia.org/api/rest_v1/media/math/render/svg/458a728f53b9a0274f059cd695e067c430956025)는  m × m 크기를 가지는 유니터리 행렬이다.
#
# ![시그마](https://wikimedia.org/api/rest_v1/media/math/render/svg/9e1f558f53cda207614abdf90162266c70bc5c1e)는 m × n 크기를 가지며, 대각선상에 있는 원소의 값은 음수가 아니며 나머지 원소의 값이 모두 0인 대각행렬이다.
#
# ![V](https://wikimedia.org/api/rest_v1/media/math/render/svg/5910e6a94f4f7ee2ee85ceed9dacef3eff7a6242)는 V의 켤레전치 행렬로, n × n 유니터리 행렬이다.

# %% [markdown]
# ## 라이브러리

# %%
import sys
# !{sys.executable} -m pip install scikit-surprise
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python3.12 -m pip install --upgrade pip

# %%
import pandas as pd

# 레시피별 포함 재료 데이터
recipe_ingredients = pd.DataFrame({
    'recipe_id': [101, 102, 103],
    'ingredients': ['소고기, 양파, 간장', '계란, 양파, 소금', '소고기, 무, 마늘']
})

# 사용자 과거 평점 데이터 (Surprise용)
ratings_data = pd.DataFrame({
    'user_id': ['성빈', '성빈', '유저B'],
    'recipe_id': [101, 103, 101],
    'rating': [5, 4, 2]
})
